# %%
# %matplotlib inline
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import plot_histogram

# %% [markdown]
# ### gates applied to the first qubit doesn't affect statistics.

# %%
mycircuit = QuantumCircuit(2,2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.measure(0,0)
mycircuit.measure(1,1)
mycircuit.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
plot_histogram(counts)

# %%
mycircuit = QuantumCircuit(2,2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.x(0)
mycircuit.measure(0,0)
mycircuit.measure(1,1)
mycircuit.draw()
# Out:
#      ┌───┐     ┌───┐┌─┐
# q_0: ┤ H ├──■──┤ X ├┤M├
#      └───┘┌─┴─┐└┬─┬┘└╥┘
# q_1: ─────┤ X ├─┤M├──╫─
#           └───┘ └╥┘  ║
# c: 2/════════════╩═══╩═
#                  1   0

# %%
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
plot_histogram(counts)

# %%
mycircuit = QuantumCircuit(2,2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.z(0)
mycircuit.measure(0,0)
mycircuit.measure(1,1)
mycircuit.draw()
# Out:
#      ┌───┐     ┌───┐┌─┐
# q_0: ┤ H ├──■──┤ Z ├┤M├
#      └───┘┌─┴─┐└┬─┬┘└╥┘
# q_1: ─────┤ X ├─┤M├──╫─
#           └───┘ └╥┘  ║
# c: 2/════════════╩═══╩═
#                  1   0

# %%
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
plot_histogram(counts)

# %% [markdown]
# ### gates applied to the second qubit doesn't affect statistics.

# %%
mycircuit = QuantumCircuit(2,2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.x(1)
mycircuit.measure(0,0)
mycircuit.measure(1,1)
mycircuit.draw()
# Out:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├───
#      └───┘┌─┴─┐┌───┐└╥┘┌─┐
# q_1: ─────┤ X ├┤ X ├─╫─┤M├
#           └───┘└───┘ ║ └╥┘
# c: 2/════════════════╩══╩═
#                      0  1

# %%
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
plot_histogram(counts)

# %%
mycircuit = QuantumCircuit(2,2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.x(1)
mycircuit.measure(0,0)
mycircuit.measure(1,1)
mycircuit.draw()

# %%
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
plot_histogram(counts)

# %%
mycircuit = QuantumCircuit(2,2)
mycircuit.h(0)
mycircuit.cx(0,1)
mycircuit.z(1)
mycircuit.measure(0,0)
mycircuit.measure(1,1)
mycircuit.draw()
# Out:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├───
#      └───┘┌─┴─┐┌───┐└╥┘┌─┐
# q_1: ─────┤ X ├┤ Z ├─╫─┤M├
#           └───┘└───┘ ║ └╥┘
# c: 2/════════════════╩══╩═
#                      0  1

# %%
simulator = Aer.get_backend('qasm_simulator')
counts = execute(mycircuit, backend=simulator, shots=1000).result().get_counts(mycircuit)
plot_histogram(counts)
